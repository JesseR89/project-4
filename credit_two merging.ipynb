# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report
from pandas import DataFrame
from pandas import Series
from scipy.stats import linregress
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import warnings
import csv
import os

# %%
test_df = pd.read_csv('test.csv')

# %%
#Rename the test dateFrame columns 
test_df.rename(columns = {'Credit_Utilization_Ratio':'Credit Utilization Ratio'}, inplace=True)

# %%
test_df.head()
# Out:
#        ID Customer_ID      Month             Name Age          SSN Occupation  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh  23  821-00-0265  Scientist
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh  24  821-00-0265  Scientist
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh  24  821-00-0265  Scientist
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24  821-00-0265  Scientist
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj  28  004-07-5839    _______
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      19114.12            1824.843333                  3  ...
# 1      19114.12            1824.843333                  3  ...
# 2      19114.12            1824.843333                  3  ...
# 3      19114.12                    NaN                  3  ...
# 4      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit Utilization Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 2                   4.0        Good           809.98                33.811894
# 3                   4.0        Good           809.98                32.430559
# 4                   5.0        Good           605.03                25.926822
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 2                     NaN                    No           49.574949
# 3   23 Years and 0 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour Monthly_Balance
# 0               236.642682    Low_spent_Small_value_payments     186.2667021
# 1              21.46538026  High_spent_Medium_value_payments     361.4440039
# 2              148.2339379   Low_spent_Medium_value_payments     264.6754462
# 3              39.08251089  High_spent_Medium_value_payments     343.8268732
# 4              39.68401842   High_spent_Large_value_payments     485.2984337
#
# [5 rows x 27 columns]

# %%
credit_df = pd.read_csv('credit_risk_dataset.csv')

# %%
#Rename credit risk column 
credit_df.rename(columns = {'person_income':'Annual_Income'}, inplace=True)

#Rename credit risk column
credit_df.rename(columns = {'loan_int_rate':'Interest_Rate'}, inplace=True)
# Out:
#    person_age  Annual_Income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  Interest_Rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
credit_df.head()
# Out:
#    person_age  Annual_Income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  Interest_Rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
credit_df.head()
# Out:
#    person_age  Annual_Income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  Interest_Rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
credit_scoring_df = pd.read_csv('credit_scoring.csv')
credit_scoring_df.head()
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
# 4   32    Male        Married        Bachelor     Self-Employed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
# 2                      0.22             2771                          6
# 3                      0.12             1371                          2
# 4                      0.99              828                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan
# 2       957000           2.76         12      Auto Loan
# 3      4731000           6.57         60      Auto Loan
# 4      3289000           6.28         36  Personal Loan

# %%
test_df.dropna(inplace=True)
test_df.head()
# Out:
#        ID Customer_ID      Month             Name Age          SSN Occupation  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh  23  821-00-0265  Scientist
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh  24  821-00-0265  Scientist
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj  28  004-07-5839    _______
# 5  0x1617  CUS_0x21b1    October  Rick Rothackerj  28    #F%$D@*&8    Teacher
# 7  0x1619  CUS_0x21b1   December  Rick Rothackerj  28  004-07-5839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      19114.12            1824.843333                  3  ...
# 1      19114.12            1824.843333                  3  ...
# 4      34847.84            3037.986667                  2  ...
# 5      34847.84            3037.986667                  2  ...
# 7      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit Utilization Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 4                   5.0        Good           605.03                25.926822
# 5                   5.0        Good           605.03                30.116600
# 7                   5.0           _           605.03                33.875167
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
# 5   27 Years and 4 Months                    No           18.816215
# 7   27 Years and 6 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour Monthly_Balance
# 0               236.642682    Low_spent_Small_value_payments     186.2667021
# 1              21.46538026  High_spent_Medium_value_payments     361.4440039
# 4              39.68401842   High_spent_Large_value_payments     485.2984337
# 5              251.6273688    Low_spent_Large_value_payments     303.3550833
# 7              153.5344876                            !@9#%8     421.4479645
#
# [5 rows x 27 columns]

# %%
credit_df.dropna(inplace=True)
credit_df.head()
# Out:
#    person_age  Annual_Income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  Interest_Rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
credit_scoring_df.dropna(inplace=True)
credit_scoring_df.head()
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
# 4   32    Male        Married        Bachelor     Self-Employed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
# 2                      0.22             2771                          6
# 3                      0.12             1371                          2
# 4                      0.99              828                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan
# 2       957000           2.76         12      Auto Loan
# 3      4731000           6.57         60      Auto Loan
# 4      3289000           6.28         36  Personal Loan

# %%
test_df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit Utilization Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')

# %%
credit_df.columns
# Out:
# Index(['person_age', 'Annual_Income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'Interest_Rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
credit_scoring_df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Education Level',
#        'Employment Status', 'Credit Utilization Ratio', 'Payment History',
#        'Number of Credit Accounts', 'Loan Amount', 'Interest Rate',
#        'Loan Term', 'Type of Loan'],
#       dtype='object')

# %%
#merge the DataFrames

# %%
half_concat = pd.concat([credit_df,test_df], axis=0)
half_concat
# Out:
#        person_age Annual_Income person_home_ownership  person_emp_length  \
# 0            22.0         59000                  RENT              123.0
# 1            21.0          9600                   OWN                5.0
# 2            25.0          9600              MORTGAGE                1.0
# 3            23.0         65500                  RENT                4.0
# 4            24.0         54400                  RENT                8.0
# ...           ...           ...                   ...                ...
# 49992         NaN      20002.88                   NaN                NaN
# 49993         NaN      20002.88                   NaN                NaN
# 49994         NaN      20002.88                   NaN                NaN
# 49997         NaN      39628.99                   NaN                NaN
# 49999         NaN      39628.99                   NaN                NaN
#
#       loan_intent loan_grade  loan_amnt  Interest_Rate  loan_status  \
# 0        PERSONAL          D    35000.0          16.02          1.0
# 1       EDUCATION          B     1000.0          11.14          0.0
# 2         MEDICAL          C     5500.0          12.87          1.0
# 3         MEDICAL          C    35000.0          15.23          1.0
# 4         MEDICAL          C    35000.0          14.27          1.0
# ...           ...        ...        ...            ...          ...
# 49992         NaN        NaN        NaN          29.00          NaN
# 49993         NaN        NaN        NaN          29.00          NaN
# 49994         NaN        NaN        NaN          29.00          NaN
# 49997         NaN        NaN        NaN           7.00          NaN
# 49999         NaN        NaN        NaN           7.00          NaN
#
#        loan_percent_income  ... Num_Credit_Inquiries  Credit_Mix  \
# 0                     0.59  ...                  NaN         NaN
# 1                     0.10  ...                  NaN         NaN
# 2                     0.57  ...                  NaN         NaN
# 3                     0.53  ...                  NaN         NaN
# 4                     0.55  ...                  NaN         NaN
# ...                    ...  ...                  ...         ...
# 49992                  NaN  ...                  9.0         Bad
# 49993                  NaN  ...                 12.0         Bad
# 49994                  NaN  ...                 12.0         Bad
# 49997                  NaN  ...                  7.0        Good
# 49999                  NaN  ...                  7.0           _
#
#       Outstanding_Debt Credit Utilization Ratio     Credit_History_Age  \
# 0                  NaN                      NaN                    NaN
# 1                  NaN                      NaN                    NaN
# 2                  NaN                      NaN                    NaN
# 3                  NaN                      NaN                    NaN
# 4                  NaN                      NaN                    NaN
# ...                ...                      ...                    ...
# 49992           3571.7                32.391288   6 Years and 4 Months
# 49993           3571.7                37.528511   6 Years and 5 Months
# 49994           3571.7                27.027812   6 Years and 6 Months
# 49997           502.38                36.858542  32 Years and 0 Months
# 49999           502.38                34.108530  32 Years and 2 Months
#
#       Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                       NaN                 NaN                     NaN
# 1                       NaN                 NaN                     NaN
# 2                       NaN                 NaN                     NaN
# 3                       NaN                 NaN                     NaN
# 4                       NaN                 NaN                     NaN
# ...                     ...                 ...                     ...
# 49992                   Yes           60.964772             107.2107416
# 49993                   Yes           60.964772             71.79442083
# 49994                   Yes           60.964772              50.8468468
# 49997                    No           35.104023               __10000__
# 49999                    No           35.104023             220.4578781
#
#                      Payment_Behaviour  Monthly_Balance
# 0                                  NaN              NaN
# 1                                  NaN              NaN
# 2                                  NaN              NaN
# 3                                  NaN              NaN
# 4                                  NaN              NaN
# ...                                ...              ...
# 49992   Low_spent_Small_value_payments      314.8151526
# 49993   Low_spent_Small_value_payments      350.2314735
# 49994  High_spent_Small_value_payments      341.1790475
# 49997   Low_spent_Large_value_payments      349.7263321
# 49999  Low_spent_Medium_value_payments      360.3796826
#
# [59040 rows x 37 columns]

# %%
combined_df.columns
# Out:
# Index(['person_age', 'Annual_Income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'Interest_Rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length', 'ID',
#        'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit Utilization Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')

# %%
full_concat = pd.concat([half_concat,credit_scoring_df], axis=0)
full_concat.head()
# Out:
#    person_age Annual_Income person_home_ownership  person_emp_length  \
# 0        22.0         59000                  RENT              123.0
# 1        21.0          9600                   OWN                5.0
# 2        25.0          9600              MORTGAGE                1.0
# 3        23.0         65500                  RENT                4.0
# 4        24.0         54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  Interest_Rate  loan_status  \
# 0    PERSONAL          D    35000.0          16.02          1.0
# 1   EDUCATION          B     1000.0          11.14          0.0
# 2     MEDICAL          C     5500.0          12.87          1.0
# 3     MEDICAL          C    35000.0          15.23          1.0
# 4     MEDICAL          C    35000.0          14.27          1.0
#
#    loan_percent_income  ... Gender  Marital Status Education Level  \
# 0                 0.59  ...    NaN             NaN             NaN
# 1                 0.10  ...    NaN             NaN             NaN
# 2                 0.57  ...    NaN             NaN             NaN
# 3                 0.53  ...    NaN             NaN             NaN
# 4                 0.55  ...    NaN             NaN             NaN
#
#   Employment Status Payment History Number of Credit Accounts Loan Amount  \
# 0               NaN             NaN                       NaN         NaN
# 1               NaN             NaN                       NaN         NaN
# 2               NaN             NaN                       NaN         NaN
# 3               NaN             NaN                       NaN         NaN
# 4               NaN             NaN                       NaN         NaN
#
#   Interest Rate Loan Term  Type of Loan
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
#
# [5 rows x 47 columns]

# %%
full_concat.columns
# Out:
# Index(['person_age', 'Annual_Income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'Interest_Rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length', 'ID',
#        'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit Utilization Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Gender', 'Marital Status', 'Education Level', 'Employment Status',
#        'Payment History', 'Number of Credit Accounts', 'Loan Amount',
#        'Interest Rate', 'Loan Term', 'Type of Loan'],
#       dtype='object')

# %%
full_concat = pd.Series(['Age','Annual_Income','Credit Utilization Ratio','Interest_Rate'])

# %%
full_concat.head()
# Out:
# 0                         Age
# 1               Annual_Income
# 2    Credit Utilization Ratio
# 3               Interest_Rate
# dtype: object
