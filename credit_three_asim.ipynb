# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report
from pandas import DataFrame
from pandas import Series
from scipy.stats import linregress
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import warnings
import csv
import os 
from collections import Counter

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#        ID Customer_ID      Month             Name Age          SSN Occupation  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh  23  821-00-0265  Scientist
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh  24  821-00-0265  Scientist
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh  24  821-00-0265  Scientist
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24  821-00-0265  Scientist
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj  28  004-07-5839    _______
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      19114.12            1824.843333                  3  ...
# 1      19114.12            1824.843333                  3  ...
# 2      19114.12            1824.843333                  3  ...
# 3      19114.12                    NaN                  3  ...
# 4      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 2                   4.0        Good           809.98                33.811894
# 3                   4.0        Good           809.98                32.430559
# 4                   5.0        Good           605.03                25.926822
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 2                     NaN                    No           49.574949
# 3   23 Years and 0 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour Monthly_Balance
# 0               236.642682    Low_spent_Small_value_payments     186.2667021
# 1              21.46538026  High_spent_Medium_value_payments     361.4440039
# 2              148.2339379   Low_spent_Medium_value_payments     264.6754462
# 3              39.08251089  High_spent_Medium_value_payments     343.8268732
# 4              39.68401842   High_spent_Large_value_payments     485.2984337
#
# [5 rows x 27 columns]

# %%
credit_df = pd.read_csv('credit_risk_dataset.csv')
credit_df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
credit_scoring_df = pd.read_csv('credit_scoring.csv')
credit_scoring_df.head()
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
# 4   32    Male        Married        Bachelor     Self-Employed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
# 2                      0.22             2771                          6
# 3                      0.12             1371                          2
# 4                      0.99              828                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan
# 2       957000           2.76         12      Auto Loan
# 3      4731000           6.57         60      Auto Loan
# 4      3289000           6.28         36  Personal Loan

# %%
test_df.dropna(inplace=True)
test_df.head()
# Out:
#        ID Customer_ID      Month             Name Age          SSN Occupation  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh  23  821-00-0265  Scientist
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh  24  821-00-0265  Scientist
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj  28  004-07-5839    _______
# 5  0x1617  CUS_0x21b1    October  Rick Rothackerj  28    #F%$D@*&8    Teacher
# 7  0x1619  CUS_0x21b1   December  Rick Rothackerj  28  004-07-5839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      19114.12            1824.843333                  3  ...
# 1      19114.12            1824.843333                  3  ...
# 4      34847.84            3037.986667                  2  ...
# 5      34847.84            3037.986667                  2  ...
# 7      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 4                   5.0        Good           605.03                25.926822
# 5                   5.0        Good           605.03                30.116600
# 7                   5.0           _           605.03                33.875167
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
# 5   27 Years and 4 Months                    No           18.816215
# 7   27 Years and 6 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour Monthly_Balance
# 0               236.642682    Low_spent_Small_value_payments     186.2667021
# 1              21.46538026  High_spent_Medium_value_payments     361.4440039
# 4              39.68401842   High_spent_Large_value_payments     485.2984337
# 5              251.6273688    Low_spent_Large_value_payments     303.3550833
# 7              153.5344876                            !@9#%8     421.4479645
#
# [5 rows x 27 columns]

# %%
credit_df.dropna(inplace=True)
credit_df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
credit_scoring_df.dropna(inplace=True)
credit_scoring_df.head()
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
# 4   32    Male        Married        Bachelor     Self-Employed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
# 2                      0.22             2771                          6
# 3                      0.12             1371                          2
# 4                      0.99              828                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan
# 2       957000           2.76         12      Auto Loan
# 3      4731000           6.57         60      Auto Loan
# 4      3289000           6.28         36  Personal Loan

# %%
test_df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')

# %%
credit_df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
credit_scoring_df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Education Level',
#        'Employment Status', 'Credit Utilization Ratio', 'Payment History',
#        'Number of Credit Accounts', 'Loan Amount', 'Interest Rate',
#        'Loan Term', 'Type of Loan'],
#       dtype='object')

# %%
credit_scoring_df.dtypes
# Out:
# Age                            int64
# Gender                        object
# Marital Status                object
# Education Level               object
# Employment Status             object
# Credit Utilization Ratio     float64
# Payment History                int64
# Number of Credit Accounts      int64
# Loan Amount                    int64
# Interest Rate                float64
# Loan Term                      int64
# Type of Loan                  object
# dtype: object

# %%
credit_df.dtypes
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_status                     int64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %%
test_df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# dtype: object

# %%
#Rename the test dateFrame columns 
test_df.rename(columns = {'Credit_Utilization_Ratio':'Credit Utilization Ratio'}, inplace=True)
test_df.head()
# Out:
#        ID Customer_ID      Month             Name Age          SSN Occupation  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh  23  821-00-0265  Scientist
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh  24  821-00-0265  Scientist
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj  28  004-07-5839    _______
# 5  0x1617  CUS_0x21b1    October  Rick Rothackerj  28    #F%$D@*&8    Teacher
# 7  0x1619  CUS_0x21b1   December  Rick Rothackerj  28  004-07-5839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      19114.12            1824.843333                  3  ...
# 1      19114.12            1824.843333                  3  ...
# 4      34847.84            3037.986667                  2  ...
# 5      34847.84            3037.986667                  2  ...
# 7      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit Utilization Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 4                   5.0        Good           605.03                25.926822
# 5                   5.0        Good           605.03                30.116600
# 7                   5.0           _           605.03                33.875167
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
# 5   27 Years and 4 Months                    No           18.816215
# 7   27 Years and 6 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour Monthly_Balance
# 0               236.642682    Low_spent_Small_value_payments     186.2667021
# 1              21.46538026  High_spent_Medium_value_payments     361.4440039
# 4              39.68401842   High_spent_Large_value_payments     485.2984337
# 5              251.6273688    Low_spent_Large_value_payments     303.3550833
# 7              153.5344876                            !@9#%8     421.4479645
#
# [5 rows x 27 columns]

# %%
#Rename credit risk column
credit_df.rename(columns = {'loan_int_rate':'Interest_Rate'}, inplace=True)
credit_df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  Interest_Rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
#Rename credit risk column 
credit_df.rename(columns = {'person_income':'Annual_Income'}, inplace=True)
credit_df.head()
# Out:
#    person_age  Annual_Income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  Interest_Rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
#merge the DataFrames

# %%
#Credit utilization of lesser than .30 , Optimal credit utilization
filtered_credit_scoring_df = credit_scoring_df.loc[credit_scoring_df["Credit Utilization Ratio"]<=.30]
filtered_credit_scoring_df.head()
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
# 9   60    Male       Divorced             PhD        Unemployed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
# 2                      0.22             2771                          6
# 3                      0.12             1371                          2
# 9                      0.06             1371                         10
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan
# 2       957000           2.76         12      Auto Loan
# 3      4731000           6.57         60      Auto Loan
# 9      4026000          11.05         60  Personal Loan

# %%
filtered_credit_scoring_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        295 non-null    int64
#  1   Gender                     295 non-null    object
#  2   Marital Status             295 non-null    object
#  3   Education Level            295 non-null    object
#  4   Employment Status          295 non-null    object
#  5   Credit Utilization Ratio   295 non-null    float64
#  6   Payment History            295 non-null    int64
#  7   Number of Credit Accounts  295 non-null    int64
#  8   Loan Amount                295 non-null    int64
#  9   Interest Rate              295 non-null    float64
#  10  Loan Term                  295 non-null    int64
#  11  Type of Loan               295 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 30.0+ KB

# %%
def assign_classes(ratio):
    if ratio < 0.1:
        return 1
    elif ratio < 0.2:
        return 2
    elif ratio < 0.3:
        return 3

y_train['target'] = y_train['Credit Utilization Ratio'].apply(assign_classes)

# %%
filtered_credit_scoring_df['target'] = filtered_credit_scoring_df['Credit Utilization Ratio'].apply(assign_classes)
# Out:
# C:\Users\iam4C\AppData\Local\Temp\ipykernel_6292\2775944341.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_credit_scoring_df['target'] = filtered_credit_scoring_df['Credit Utilization Ratio'].apply(assign_classes)

# %%
filtered_credit_scoring_df.dropna(subset = 'target', inplace=True)
# Out:
# C:\Users\iam4C\AppData\Local\Temp\ipykernel_6292\1071988637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_credit_scoring_df.dropna(subset = 'target', inplace=True)

# %%
target = ["target"]
# Create our features
X = filtered_credit_scoring_df.drop(["Credit Utilization Ratio", "target"], axis=1)
X = pd.get_dummies(X)

# Create our target
y = filtered_credit_scoring_df.loc[:, target].copy()

# %%
X.describe()
# Out:
#               Age  Payment History  Number of Credit Accounts   Loan Amount  \
# count  285.000000       285.000000                 285.000000  2.850000e+02
# mean    42.347368      1468.768421                   5.540351  2.562677e+06
# std     13.140172       845.016636                   3.071212  1.451216e+06
# min     20.000000         0.000000                   1.000000  1.270000e+05
# 25%     31.000000       742.000000                   3.000000  1.251000e+06
# 50%     42.000000      1400.000000                   6.000000  2.500000e+06
# 75%     53.000000      2200.000000                   8.000000  3.887000e+06
# max     65.000000      2857.000000                  10.000000  4.970000e+06
#
#        Interest Rate   Loan Term
# count     285.000000  285.000000
# mean       10.345754   38.315789
# std         5.388302   17.649919
# min         1.010000   12.000000
# 25%         6.170000   24.000000
# 50%        10.390000   36.000000
# 75%        15.160000   60.000000
# max        19.960000   60.000000

# %%
# Check the balance of our target values
y['target'].value_counts()
# Out:
# target
# 2.0    110
# 1.0     90
# 3.0     85
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
print(Counter(y_train['target']))
print(Counter(y_test['target']))
# Out:
# Counter({2.0: 86, 1.0: 65, 3.0: 62})
# Counter({1.0: 25, 2.0: 24, 3.0: 23})

# %%
y_train['target'].describe()
# Out:
# count    213.000000
# mean       1.985915
# std        0.773859
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        3.000000
# Name: target, dtype: float64

# %%
y_train['target'].value_counts()
# Out:
# target
# 2.0    86
# 1.0    65
# 3.0    62
# Name: count, dtype: int64

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
logistic_regression_model = LogisticRegression()

# Fit the model using training data
lr_model = logistic_regression_model.fit(X_train, y_train)
# Out:
# C:\Users\iam4C\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Make a prediction using the testing data
test_predictions = logistic_regression_model.predict(X_test)

# %%
test_predictions
# Out:
# array([2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2.])

# %%
# Generate a confusion matrix for the model
cf_test_matrix = confusion_matrix(y_test, test_predictions)
cf_test_matrix
# Out:
# array([[ 0, 25,  0],
#        [ 0, 24,  0],
#        [ 0, 23,  0]], dtype=int64)

# %%
# Print the classification report for the model
testing_report = classification_report(y_test, test_predictions)
print(testing_report)
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        25
#          2.0       0.33      1.00      0.50        24
#          3.0       0.00      0.00      0.00        23
#
#     accuracy                           0.33        72
#    macro avg       0.11      0.33      0.17        72
# weighted avg       0.11      0.33      0.17        72
# C:\Users\iam4C\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\iam4C\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\iam4C\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fig = px.box(test_df,
            x = "Annual Income",
            y = "target",
            color = "Credit Utilization",
            title = "Annual Income & credit Utilization",
            color_discrete_map={'Poor':'red',
                                 'Standard':'yellow',
                               'Good':"green"})
                                 
fig.update_traces(quartilemethod="exclusive")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 fig = px.box(test_df,
#       2             x = "Annual Income",
#       3             y = "target",
#       4             color = "Credit Utilization",
#       5             title = "Annual Income & credit Utilization",
#       6             color_discrete_map={'Poor':'red',
#       7                                  'Standard':'yellow',
#       8                                'Good':"green"})
#      10 fig.update_traces(quartilemethod="exclusive")
#      11 fig.show()
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:666, in box(data_frame, x, y, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, orientation, boxmode, log_x, log_y, range_x, range_y, points, notched, title, template, width, height)
#     625 def box(
#     626     data_frame=None,
#     627     x=None,
#    (...)
#     655     height=None,
#     656 ) -> go.Figure:
#     657     """
#     658     In a box plot, rows of `data_frame` are grouped together into a
#     659     box-and-whisker mark to visualize their distribution.
#    (...)
#     664     range (IQR: Q3-Q1), see "points" for other options.
#     665     """
# --> 666     return make_figure(
#     667         args=locals(),
#     668         constructor=go.Box,
#     669         trace_patch=dict(boxpoints=points, notched=notched, x0=" ", y0=" "),
#     670         layout_patch=dict(boxmode=boxmode),
#     671     )
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:1207, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt', 'Credit Utilization Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'] but received: Annual Income

# %%
fig = px.box(data, 
             x="Occupation",  
             color="Credit_Score", 
             title="Credit Scores Based on Occupation", 
             color_discrete_map={'Poor':'red',
                                 'Standard':'yellow',
                                 'Good':"Green"})
fig.show()
